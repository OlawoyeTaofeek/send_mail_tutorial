# %% [markdown]
# ### Understanding the conceots for the project

# %%
## Context manager

with open("data/Birthday_Wish_Template.txt", "r", encoding="utf-8") as f:
    output = f.read()

print(output)
# Out:
# Subject: Happy Birthday, {name}! 🎉
#
# Dear {name},
#
# Happy Birthday!
#
# On this special day, I want to wish you a year filled with happiness, good health, success, and countless unforgettable moments. May every goal you set be within reach, every challenge become an opportunity for growth, and every day bring new reasons to smile.
#
# Your kindness, determination, and the positive impact you have on the people around you make you truly special. Today is not only a celebration of another year of life but also a celebration of the wonderful person you are.
#
# May this new chapter bring exciting opportunities, cherished memories, meaningful connections, and all the happiness your heart can hold. Never stop believing in yourself, because the best is yet to come.
#
# Enjoy your day to the fullest, surround yourself with the people you love, and create beautiful memories that will last a lifetime.
#
# ...

# %%
def read_file(filepath: str):
    with open(filepath, "r", encoding="utf-8") as f:
        output = f.read()
    return output

# %%
read_file("data/Birthday_Wish_Template.txt")
# Out:
# 'Subject: Happy Birthday, {name}! 🎉\n\nDear {name},\n\nHappy Birthday!\n\nOn this special day, I want to wish you a year filled with happiness, good health, success, and countless unforgettable moments. May every goal you set be within reach, every challenge become an opportunity for growth, and every day bring new reasons to smile.\n\nYour kindness, determination, and the positive impact you have on the people around you make you truly special. Today is not only a celebration of another year of life but also a celebration of the wonderful person you are.\n\nMay this new chapter bring exciting opportunities, cherished memories, meaningful connections, and all the happiness your heart can hold. Never stop believing in yourself, because the best is yet to come.\n\nEnjoy your day to the fullest, surround yourself with the people you love, and create beautiful memories that will last a lifetime.\n\nOnce again, Happy Birthday, {name}! May your year ahead be as amazing and inspiring as you
# ...

# %%
def modify(output: str, name: str, your_name: str):
    new_output = output.replace("{name}", name).replace("[Your Name]", your_name)

    return new_output

# %%
print(modify(read_file("data/Birthday_Wish_Template.txt"), "Inioluwa", "Taofeek"))
# Out:
# Subject: Happy Birthday, Inioluwa! 🎉
#
# Dear Inioluwa,
#
# Happy Birthday!
#
# On this special day, I want to wish you a year filled with happiness, good health, success, and countless unforgettable moments. May every goal you set be within reach, every challenge become an opportunity for growth, and every day bring new reasons to smile.
#
# Your kindness, determination, and the positive impact you have on the people around you make you truly special. Today is not only a celebration of another year of life but also a celebration of the wonderful person you are.
#
# May this new chapter bring exciting opportunities, cherished memories, meaningful connections, and all the happiness your heart can hold. Never stop believing in yourself, because the best is yet to come.
#
# Enjoy your day to the fullest, surround yourself with the people you love, and create beautiful memories that will last a lifetime.
#
# ...

# %%
# !pip install dotenv
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import smtplib  
import os

with smtplib.SMTP("smtp.gmail.com", 587) as connection:
    connection.starttls()
    connection.login(user=os.getenv("my_email"), password=os.getenv("my_password"))
    connection.sendmail(
        from_addr=os.getenv("my_email"), 
        to_addrs="ayetoroinioluwa@gmail.com",
        msg=modify(read_file("data/Birthday_Wish_Template.txt"), "Inioluwa", "Taofeek").encode("utf-8")
    )

# %%
"""
Birthday Email Generator & Sender
----------------------------------
Takes a personalized birthday message (with {name} already replaced) and
wraps it in a polished, mobile-friendly HTML email, then sends it via SMTP.

Usage:
    from birthday_email import build_birthday_email, send_birthday_email

    html = build_birthday_email(name="Sarah", body_text=my_filled_message)
    send_birthday_email(
        to_email="sarah@example.com",
        subject="Happy Birthday, Sarah! 🎉",
        html_content=html,
        smtp_user="you@gmail.com",
        smtp_password="your-app-password",
    )
"""

import re
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText


def build_birthday_email(name: str, body_text: str, sender_name: str = "") -> str:
    """
    Wrap a plain-text birthday message into a polished HTML email.

    Args:
        name: The recipient's name (used in the header/banner).
        body_text: The full personalized message (the text you already
                   filled {name} into). Paragraphs should be separated
                   by blank lines (\\n\\n).
        sender_name: Optional override for the signature line. If not
                     provided, the function tries to detect a trailing
                     "Warmest wishes,\\nX" style signature in body_text
                     and keep it; otherwise leaves it as-is.

    Returns:
        A full HTML document (string) ready to use as the email's HTML body.
    """

    # Split the message into paragraphs based on blank lines
    raw_paragraphs = [p.strip() for p in re.split(r"\n\s*\n", body_text.strip()) if p.strip()]

    # Convert each paragraph into an HTML <p>, preserving single line breaks as <br>
    html_paragraphs = []
    for para in raw_paragraphs:
        para_html = para.replace("\n", "<br>")
        html_paragraphs.append(f'<p style="margin:0 0 20px 0; font-size:16px; line-height:1.7; color:#444444;">{para_html}</p>')

    body_html = "\n".join(html_paragraphs)

    html = f"""<!DOCTYPE html>
<html lang="en">
<head>
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
<title>Happy Birthday, {name}!</title>
</head>
<body style="margin:0; padding:0; background-color:#f4f1ec; font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
  <table role="presentation" width="100%" cellpadding="0" cellspacing="0" style="background-color:#f4f1ec; padding:40px 0;">
    <tr>
      <td align="center">
        <table role="presentation" width="600" cellpadding="0" cellspacing="0" style="max-width:600px; width:100%; background-color:#ffffff; border-radius:16px; overflow:hidden; box-shadow:0 8px 30px rgba(0,0,0,0.08);">

          <!-- Header banner -->
          <tr>
            <td style="background:linear-gradient(135deg, #ff7e5f 0%, #feb47b 50%, #ff6a88 100%); padding:50px 30px; text-align:center;">
              <div style="font-size:48px; line-height:1; margin-bottom:10px;">🎉🎂🎈</div>
              <h1 style="margin:0; font-size:32px; color:#ffffff; font-weight:700; letter-spacing:0.5px; text-shadow:0 2px 6px rgba(0,0,0,0.15);">
                Happy Birthday, {name}!
              </h1>
            </td>
          </tr>

          <!-- Body -->
          <tr>
            <td style="padding:40px 40px 20px 40px;">
              {body_html}
            </td>
          </tr>

          <!-- Decorative divider -->
          <tr>
            <td style="padding:0 40px;">
              <div style="height:1px; background-color:#eeeeee; margin:10px 0 30px 0;"></div>
            </td>
          </tr>

          <!-- Footer -->
          <tr>
            <td style="padding:0 40px 40px 40px; text-align:center;">
              <div style="font-size:28px; margin-bottom:8px;">🎈🥳🎁</div>
              <p style="margin:0; font-size:13px; color:#aaaaaa;">Sent with love, on your special day.</p>
            </td>
          </tr>

        </table>
      </td>
    </tr>
  </table>
</body>
</html>"""

    return html


def send_birthday_email(
    to_email: str,
    subject: str,
    html_content: str,
    smtp_user: str,
    smtp_password: str,
    smtp_host: str = "smtp.gmail.com",
    smtp_port: int = 587,
    plain_text_fallback: str = None,
):
    """
    Send the HTML birthday email via SMTP (defaults configured for Gmail).

    Args:
        to_email: Recipient's email address.
        subject: Email subject line.
        html_content: HTML body, e.g. from build_birthday_email().
        smtp_user: Your sending email address.
        smtp_password: Your email account password or app password
                        (for Gmail, use an App Password, not your normal password).
        smtp_host: SMTP server host (default: Gmail).
        smtp_port: SMTP server port (default: 587, STARTTLS).
        plain_text_fallback: Optional plain-text version for email clients
                              that don't render HTML. If not given, a simple
                              fallback is auto-generated.
    """
    msg = MIMEMultipart("alternative")
    msg["Subject"] = subject
    msg["From"] = smtp_user
    msg["To"] = to_email

    if plain_text_fallback is None:
        plain_text_fallback = "Happy Birthday! (View this email in HTML for the full experience.)"

    msg.attach(MIMEText(plain_text_fallback, "plain"))
    msg.attach(MIMEText(html_content, "html"))

    with smtplib.SMTP(smtp_host, smtp_port) as server:
        server.starttls()
        server.login(smtp_user, smtp_password)
        server.sendmail(smtp_user, to_email, msg.as_string())


# if __name__ == "__main__":
#     # Example usage with your message, name already filled in
#     sample_message = """Dear Sarah,

# Happy Birthday!

# On this special day, I want to wish you a year filled with happiness, good health, success, and countless unforgettable moments. May every goal you set be within reach, every challenge become an opportunity for growth, and every day bring new reasons to smile.

# Your kindness, determination, and the positive impact you have on the people around you make you truly special. Today is not only a celebration of another year of life but also a celebration of the wonderful person you are.

# May this new chapter bring exciting opportunities, cherished memories, meaningful connections, and all the happiness your heart can hold. Never stop believing in yourself, because the best is yet to come.

# Enjoy your day to the fullest, surround yourself with the people you love, and create beautiful memories that will last a lifetime.

# Once again, Happy Birthday, Sarah! May your year ahead be as amazing and inspiring as you are.

# Warmest wishes,
# Alex"""

#     html_email = build_birthday_email(name="Sarah", body_text=sample_message)

#     # Save a local copy you can preview in a browser before sending
#     with open("preview_email.html", "w", encoding="utf-8") as f:
#         f.write(html_email)

#     print("Preview saved to preview_email.html — open it in your browser to check it looks right.")

#     # Uncomment to actually send:
#     # send_birthday_email(
#     #     to_email="sarah@example.com",
#     #     subject="Happy Birthday, Sarah! 🎉",
#     #     html_content=html_email,
#     #     smtp_user="you@gmail.com",
#     #     smtp_password="your-app-password",
#     # )

# %%
my_dict = {}

my_dict['name'] = "Taofeek"
my_dict
# Out:
# {'name': 'Taofeek'}

# %%
def main(name: str = None):
    if name:
        return f"Hello {name}"
    else:
        return "Hello"
    
main()
# Out:
# 'Hello'

# %%
def send_birthday_email(
    to_email: str,
    subject: str,
    html_content: str,
    smtp_user: str,
    smtp_password: str,
    smtp_host: str = "smtp.gmail.com",
    smtp_port: int = 587,
    plain_content: str= None, 
):
    
    msg = MIMEMultipart("alternative")
    msg['Subject'] = subject 
    msg['From'] = smtp_user
    msg["To"] = to_email 

    if not plain_content:
        plain_content = "Happy Birthday! (View this email in HTML for the full experience.)"
    
    msg.attach(MIMEText(plain_content, "plain"))
    msg.attach(MIMEText(html_content, "html"))

    with smtplib.SMTP(smtp_host, smtp_port) as server:
        server.starttls()
        server.login(smtp_user, smtp_password)
        server.sendmail(smtp_user, to_email, msg.as_string())

content = modify(read_file("data/Birthday_Wish_Template.txt"), "Teejay", "Taofeek")
# print(content)
html = build_birthday_email(name="Teejay", body_text=content, sender_name="Taofeek")
# print(html)
send_birthday_email("jtee71708@gmail.com", "Happy Birthday, Teejay! 🎉", html, "taofeekoladipupo1709@gmail.com", os.getenv("my_password"))

# %%
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Happy Birthday, Teejay!</title>
# </head>
# <body style="margin:0; padding:0; background-color:#f4f1ec; font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#   <table role="presentation" width="100%" cellpadding="0" cellspacing="0" style="background-color:#f4f1ec; padding:40px 0;">
#     <tr>
#       <td align="center">
#         <table role="presentation" width="600" cellpadding="0" cellspacing="0" style="max-width:600px; width:100%; background-color:#ffffff; border-radius:16px; overflow:hidden; box-shadow:0 8px 30px rgba(0,0,0,0.08);">
#
#           <!-- Header banner -->
#           <tr>
#             <td style="background:linear-gradient(135deg, #ff7e5f 0%, #feb47b 50%, #ff6a88 100%); padding:50px 30px; text-align:center;">
#               <div style="font-size:48px; line-height:1; margin-bottom:10px;">🎉🎂🎈</div>
# ...
